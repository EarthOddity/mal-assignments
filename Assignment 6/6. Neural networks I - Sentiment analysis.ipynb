# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# In this exercise we use the IMDb-dataset, which we will use to perform a sentiment analysis. The code below assumes that the data is placed in the same folder as this notebook. We see that the reviews are loaded as a pandas dataframe, and print the beginning of the first few reviews.

# %%
import numpy as np
import pandas as pd
import re
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
reviews = pd.read_csv('reviews.txt', header=None, names=['review'])
labels = pd.read_csv('labels.txt', header=None, names=['label'])
Y = (labels=='positive').astype(np.int_)

print(type(reviews))
print(reviews.head())

print(type(labels))
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                               review
# 0  omwell high is a cartoon comedy . it ran at th...
# 1  story of a man who has unnatural feelings for ...
# 2  homelessness  or houselessness as george carli...
# 3  airport    starts as a and new luxury    plane...
# 4  illiant over  acting by lesley ann warren . be...
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Data Cleaning

# %%
reviews = pd.read_csv("reviews.txt", header=None, names=["review"])

reviews["review"] = reviews["review"].apply(lambda x: re.sub(r'br\s*/?', '', x, flags=re.IGNORECASE))

print(len(reviews))

# Check that the number of lines is still the same
print(f"Number of reviews after cleaning: {len(reviews)}")

# If you want to save this back to the original file (without creating a new file)
reviews.to_csv("reviews.txt", index=False, header=False, encoding="utf-8")
# Out:
# 25000
# Number of reviews after cleaning: 25000

# %% [markdown]
# **(a)** Split the reviews and labels in test, train and validation sets. The train and validation sets will be used to train your model and tune hyperparameters, the test set will be saved for testing. Use the `CountVectorizer` from `sklearn.feature_extraction.text` to create a Bag-of-Words representation of the reviews. Only use the 10,000 most frequent words (use the `max_features`-parameter of `CountVectorizer`).

# %% [markdown]
# ### Splitting the data into sets and generating a BOW

# %%
# before doing that, we want to combine labels and reviews into a single dataset
dataset = pd.concat([labels, reviews], axis=1)

# split the data into train, test, validation sets
x_train, x_test, y_train, y_test = train_test_split(reviews['review'], labels, test_size=0.2, random_state=42)
x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size=0.5, random_state=42)


x_train.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)
x_val.reset_index(drop=True, inplace=True)
y_val.reset_index(drop=True, inplace=True)
x_test.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)

print(x_train)

vectorizer = CountVectorizer(max_features=10000)
x_train_bow = vectorizer.fit_transform(x_train)

x_val_bow = vectorizer.transform(x_val)
x_test_bow = vectorizer.transform(x_test)

# get the most common words for a single review
def get_most_common_words_per_review(review, vectorizer):
    review_vector = vectorizer.transform([review])
    feature_names = np.array(vectorizer.get_feature_names_out())
    word_counts = review_vector.toarray().flatten()
    word_count_dict = dict(zip(feature_names, word_counts))
    return dict(sorted(word_count_dict.items(), key=lambda item: item[1], reverse=True))

most_common_words_single_review = get_most_common_words_per_review(reviews.iloc[3]['review'], vectorizer)
print("Most common words in a single review:", most_common_words_single_review)

# get the most popular words across all reviews
def get_most_common_words_across_reviews(reviews, vectorizer):
    reviews_vector = vectorizer.transform(reviews)
    feature_names = np.array(vectorizer.get_feature_names_out())
    word_counts = reviews_vector.toarray().sum(axis=0)
    word_count_dict = dict(zip(feature_names, word_counts))
    return dict(sorted(word_count_dict.items(), key=lambda item: item[1], reverse=True))

most_common_words_across_reviews = get_most_common_words_across_reviews(reviews['review'], vectorizer)
print("Most common words across all reviews:", most_common_words_across_reviews)
# Out:
# 0        the idea of making a miniseries about the berl...
# 1        mona the vagabond lives on the fringes of fren...
# 2        lillian hellman  one of america  s most famous...
# 3        let me be clear . i  ve used imdb for years . ...
# 4        i guess its possible that i  ve seen worse mov...
#                                ...
# 19995    it is a pity that you cannot vote zero stars o...
# 19996    david duchovney creates a role that he was to ...
# 19997    i  m a huge fan of the dukes of hazzard tv sho...
# 19998    turkish cinema has a big problem . directors a...
# 19999    in any number of films  you can find nicholas ...
# Name: review, Length: 20000, dtype: object
# Most common words in a single review: {'the': np.int64(53), 'of': np.int64(23), 'is': np.int64(14), 'to': np.int64(13), 'airport': np.int64(12), 'as': np.int64(11), 'with': np.int64(11), 'it': np.int64(10), 'this': np.int64(9), 'in': np.int64(8), 'or': np.int64(7), 'plane': np.int64(7), 'out': np.int64(6), 'while': np.int64(6), 'but': np.int64(5), 'for': np.int64(5), 'not': np.int64(5), 'air': np.int64(4), 'are': np.int64(4), 'disaster': np.int64(4), 'have': np.int64(4), 'if': np.int64(4), 'just': np.int64(4), 'little': np.int64(4), 'much': np.int64(4), 'one': np.int64(4), 'scenes': np.int64(4), 'that': np.int64(4), 'there': np.int64(4), 'three': np.int64(4), 'time': np.int64(4), 'also': np.int64(3), 'an': np.int64(3), 'by': np.int64(3), 'could': np.int64(3), 'even': np.int64(3), 'film': np.int64(3), 'films': np.int64(3), 'great': np.int64(3), 'has': np.int64(3), 'his': np.int64(3), 'on': np.int64(3), 'oscar': np.int64(3), 'other': np.int64(3), 'so': np.int64(3), 'they': np.int64(3), 'two': np.int64(3), 'winner': np.int64(3), 'about': np.int64(2), 'although': np.int64(2), 'another': np.int64(2), 'any': np.int64(2), 'been': np.int64(2), 'can': np.int64(2), 'character': np.int64(2), 'couple': np.int64(2), 'crashing': np.int64(2), 'dull': np.int64(2), 'either': np.int64(2), 'extra': np.int64(2), 'far': np.int64(2), 'flick': np.int64(2), 'flying': np.int64(2), 'footage': np.int64(2), 'george': np.int64(2), 'help': np.int64(2), 'hi': np.int64(2), 'hour': np.int64(2), 'including': np.int64(2), 'james': np.int64(2), 'kennedy': np.int64(2), 'lee': np.int64(2), 'like': np.int64(2), 'liked': np.int64(2), 'look': np.int64(2), 'looks': np.int64(2), 'luxury': np.int64(2), 'made': np.int64(2), 'mid': np.int64(2), 'minutes': np.int64(2), 'more': np.int64(2), 'new': np.int64(2), 'off': np.int64(2), 'oil': np.int64(2), 'opened': np.int64(2), 'plot': np.int64(2), 'production': np.int64(2), 'right': np.int64(2), 'say': np.int64(2), 'see': np.int64(2), 'shame': np.int64(2), 'sinks': np.int64(2), 'stevens': np.int64(2), 'stewart': np.int64(2), 'takes': np.int64(2), 'tension': np.int64(2), 'than': np.int64(2), 'up': np.int64(2), 'valuable': np.int64(2), 'was': np.int64(2), 'were': np.int64(2), 'when': np.int64(2), 'where': np.int64(2), 'who': np.int64(2), 'acting': np.int64(1), 'action': np.int64(1), 'actually': np.int64(1), 'add': np.int64(1), 'adventure': np.int64(1), 'after': np.int64(1), 'again': np.int64(1), 'almost': np.int64(1), 'along': np.int64(1), 'alright': np.int64(1), 'am': np.int64(1), 'and': np.int64(1), 'anything': np.int64(1), 'aren': np.int64(1), 'award': np.int64(1), 'back': np.int64(1), 'background': np.int64(1), 'bad': np.int64(1), 'badly': np.int64(1), 'bang': np.int64(1), 'barely': np.int64(1), 'be': np.int64(1), 'become': np.int64(1), 'behind': np.int64(1), 'being': np.int64(1), 'best': np.int64(1), 'bit': np.int64(1), 'bland': np.int64(1), 'board': np.int64(1), 'bodies': np.int64(1), 'boring': np.int64(1), 'bottom': np.int64(1), 'bunch': np.int64(1), 'businessman': np.int64(1), 'choices': np.int64(1), 'christopher': np.int64(1), 'classic': np.int64(1), 'co': np.int64(1), 'control': np.int64(1), 'course': np.int64(1), 'credits': np.int64(1), 'crew': np.int64(1), 'cross': np.int64(1), 'cut': np.int64(1), 'danger': np.int64(1), 'dated': np.int64(1), 'daughter': np.int64(1), 'dead': np.int64(1), 'decent': np.int64(1), 'descent': np.int64(1), 'design': np.int64(1), 'dialogue': np.int64(1), 'didn': np.int64(1), 'different': np.int64(1), 'dilemma': np.int64(1), 'directed': np.int64(1), 'direction': np.int64(1), 'discovery': np.int64(1), 'do': np.int64(1), 'doesn': np.int64(1), 'don': np.int64(1), 'doors': np.int64(1), 'drunk': np.int64(1), 'effects': np.int64(1), 'end': np.int64(1), 'entertained': np.int64(1), 'entertaining': np.int64(1), 'estate': np.int64(1), 'excitement': np.int64(1), 'expected': np.int64(1), 'faces': np.int64(1), 'facing': np.int64(1), 'familiar': np.int64(1), 'fashions': np.int64(1), 'fast': np.int64(1), 'fav ...
# Most common words across all reviews: {'the': np.int64(336713), 'and': np.int64(164242), 'of': np.int64(145864), 'to': np.int64(135720), 'is': np.int64(107330), 'it': np.int64(96394), 'in': np.int64(93968), 'this': np.int64(76000), 'that': np.int64(73245), 'was': np.int64(48208), 'as': np.int64(46941), 'for': np.int64(44343), 'with': np.int64(44125), 'movie': np.int64(44039), 'but': np.int64(42603), 'film': np.int64(40155), 'you': np.int64(34230), 'on': np.int64(34200), 'not': np.int64(30626), 'he': np.int64(30138), 'are': np.int64(29430), 'his': np.int64(29374), 'have': np.int64(27731), 'be': np.int64(26957), 'one': np.int64(26789), 'all': np.int64(23978), 'at': np.int64(23563), 'they': np.int64(22906), 'by': np.int64(22546), 'an': np.int64(21560), 'who': np.int64(21433), 'so': np.int64(20617), 'from': np.int64(20498), 'like': np.int64(20276), 'there': np.int64(18832), 'her': np.int64(18421), 'or': np.int64(18004), 'just': np.int64(17771), 'about': np.int64(17374), 'out': np.int64(17113), 'if': np.int64(16803), 'has': np.int64(16790), 'what': np.int64(16159), 'some': np.int64(15763), 'good': np.int64(15143), 'can': np.int64(14655), 'more': np.int64(14251), 'she': np.int64(14223), 'when': np.int64(14182), 'very': np.int64(14069), 'up': np.int64(13291), 'time': np.int64(12727), 'no': np.int64(12717), 'even': np.int64(12651), 'my': np.int64(12503), 'would': np.int64(12436), 'which': np.int64(12047), 'story': np.int64(11988), 'only': np.int64(11918), 'really': np.int64(11738), 'see': np.int64(11478), 'their': np.int64(11385), 'had': np.int64(11290), 'we': np.int64(10859), 'were': np.int64(10783), 'me': np.int64(10773), 'well': np.int64(10659), 'other': np.int64(10268), 'than': np.int64(9919), 'much': np.int64(9763), 'get': np.int64(9309), 'bad': np.int64(9308), 'been': np.int64(9289), 'people': np.int64(9285), 'will': np.int64(9211), 'do': np.int64(9177), 'also': np.int64(9158), 'into': np.int64(9111), 'first': np.int64(9061), 'great': np.int64(9059), 'because': np.int64(9045), 'how': np.int64(8901), 'him': np.int64(8876), 'don': np.int64(8804), 'most': np.int64(8783), 'made': np.int64(8364), 'its': np.int64(8311), 'then': np.int64(8119), 'make': np.int64(8025), 'way': np.int64(8025), 'them': np.int64(7970), 'could': np.int64(7923), 'too': np.int64(7833), 'movies': np.int64(7666), 'any': np.int64(7660), 'after': np.int64(7638), 'think': np.int64(7298), 'characters': np.int64(7160), 'character': np.int64(7020), 'watch': np.int64(6974), 'two': np.int64(6906), 'films': np.int64(6890), 'seen': np.int64(6679), 'many': np.int64(6675), 'life': np.int64(6628), 'being': np.int64(6610), 'plot': np.int64(6586), 'acting': np.int64(6493), 'never': np.int64(6485), 'love': np.int64(6453), 'little': np.int64(6437), 'best': np.int64(6413), 'where': np.int64(6392), 'over': np.int64(6333), 'did': np.int64(6296), 'show': np.int64(6294), 'know': np.int64(6167), 'off': np.int64(6030), 'ever': np.int64(5997), 'man': np.int64(5976), 'does': np.int64(5940), 'here': np.int64(5767), 'better': np.int64(5739), 'your': np.int64(5686), 'end': np.int64(5651), 'still': np.int64(5623), 'these': np.int64(5418), 'say': np.int64(5396), 'scene': np.int64(5383), 'why': np.int64(5318), 'while': np.int64(5317), 'scenes': np.int64(5212), 'go': np.int64(5157), 've': np.int64(5136), 'such': np.int64(5134), 'something': np.int64(5077), 'should': np.int64(5041), 'back': np.int64(4971), 'through': np.int64(4969), 'real': np.int64(4738), 'those': np.int64(4697), 'watching': np.int64(4606), 'now': np.int64(4605), 'though': np.int64(4566), 'doesn': np.int64(4536), 'thing': np.int64(4528), 'old': np.int64(4526), 'years': np.int64(4517), 're': np.int64(4504), 'actors': np.int64(4484), 'director': np.int64(4445), 'work': np.int64(4373), 'another': np.int64(4329), 'before': np.int64(4324), 'didn': np.int64(4318), 'new': np.int64(4312), 'nothing': np.int64(4290), 'funny': np.int64(4289), 'actually': np.int64(4239), 'makes': np.int64(4204), 'look': np.int64(4147), 'find': np.int64(413 ...

# %% [markdown]
# **(b)** Explore the representation of the reviews. How is a single word represented? How about a whole review?

# %% [markdown]
# ### Exploring the representation of reviews

# %%
# initialize with max 10k words
tfidf = TfidfVectorizer(
    max_features=10000,
    ngram_range=(1, 3),  # Creates combinations of 1-3 consecutive words
    min_df=2,            # Word must appear in at least 2 rows
    max_df=0.9,         # Word must appear in max 90% of the rows
    stop_words='english' # Removes common English words (such as 'and', 'to', etc.)
)

# fit on entire body of text
x_train_tfidf = tfidf.fit_transform(x_train)
x_val_tfidf = tfidf.transform(x_val)
x_test_tfidf = tfidf.transform(x_test)


# get vocabulary, should be 10k size
vocab = tfidf.get_feature_names_out()
print("Vocabulary size:", len(vocab))

# let's look at a single sample, e.g. index 0
print("OG text:", x_train[1]) # Original text
print("Word importance vector:", x_train_tfidf[1].toarray()[0], " - length:", len(x_train_tfidf[1].toarray()[0])) # TF-IDF vector (array of numbers representing word importance)

# let's match word vector vocabulary and sort by tfidf score
word_scores = {vocab[i]:score for i, score in enumerate(x_train_tfidf[1].toarray()[0]) if score > 0}
word_scores = dict(sorted(word_scores.items(), key=lambda x: x[1], reverse=True))

# Print scores without showing np.float64 format
print("Word importance scores: ", end="")
print(" | ".join([f"{word}: {score:.5f}" for word, score in word_scores.items()]))
# Out:
# Vocabulary size: 10000
# OG text: mona the vagabond lives on the fringes of french society  in a life without meaning  purpose or direction .  i watched this because of all the stellar reviews  but i  m afraid i must have missed something . the character of mona has little or no personality while drifting through life being rude to people  getting high and contributing nothing to anyone  s life . she  s not interesting or exciting . she  s just useless .  i  ve seen and known enough people like that there is no secret meaning to what they  re doing . they are just lazy bums . i wouldn  t want mona anywhere near me  as she tends to steal anything that isn  t nailed down and leave her friends in the lurch . sure she  s enigmatic  because there isn  t anything to her . lots of junkies  winos and bums i  ve seen are enigmatic i wouldn  t want to see a film about them either .  possibly there is something there that i totally missed . otherwise i  m assuming that all the reviews are from people who assume anything done by a french female director is high art .
# Word importance vector: [0. 0. 0. ... 0. 0. 0.]  - length: 10000
# Word importance scores: enigmatic: 0.31798 | wouldn want: 0.31681 | meaning: 0.22075 | french: 0.21247 | missed: 0.21133 | reviews: 0.20560 | wouldn: 0.18484 | life: 0.17632 | want film: 0.15841 | high: 0.15719 | people: 0.15660 | ve seen: 0.15649 | assuming: 0.15075 | rude: 0.14881 | tends: 0.14388 | isn: 0.14177 | stellar: 0.14035 | useless: 0.13889 | want: 0.13485 | lazy: 0.13176 | assume: 0.12626 | people like: 0.12499 | steal: 0.12474 | ve: 0.12373 | personality: 0.11716 | afraid: 0.11708 | purpose: 0.11063 | seen: 0.11040 | exciting: 0.10753 | secret: 0.10725 | society: 0.10496 | possibly: 0.10087 | lots: 0.10011 | near: 0.09712 | female: 0.09661 | art: 0.09295 | known: 0.09217 | leave: 0.09163 | totally: 0.08931 | lives: 0.08800 | direction: 0.08624 | getting: 0.08420 | doing: 0.08399 | friends: 0.08341 | just: 0.08107 | watched: 0.07670 | sure: 0.07326 | interesting: 0.07091 | director: 0.06460 | little: 0.05772 | character: 0.05739 | like: 0.03842 | film: 0.03450

# %% [markdown]
# **(c)** Train a neural network with a single hidden layer on the dataset, tuning the relevant hyperparameters to optimize accuracy.

# %% [markdown]
# **(d)** Test your sentiment-classifier on the test set.

# %% [markdown]
# **(e)** Use the classifier to classify a few sentences you write yourselves.
